# %%
! pip list | grep albumentations
# Out:
# albumentations                0.1.12

# %%
#필요한 라이브러리를 로드합니다. 
import os
import math
import numpy as np
import tensorflow as tf

from PIL import Image
import matplotlib.pyplot as plt
from skimage.io import imread
from skimage.transform import resize
from glob import glob

from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *

print('슝=3')
# Out:
# 슝=3

# %%
from albumentations import  HorizontalFlip, RandomSizedCrop, Compose, OneOf, Resize

def build_augmentation(is_train=True):
  if is_train:    # 훈련용 데이터일 경우
    return Compose([
                    HorizontalFlip(p=0.5),    # 50%의 확률로 좌우대칭
                    RandomSizedCrop(         # 50%의 확률로 RandomSizedCrop
                        min_max_height=(300, 370),
                        w2h_ratio=370/1242,
                        height=224,
                        width=224,
                        p=0.5
                        ),
                    Resize(              # 입력이미지를 224X224로 resize
                        width=224,
                        height=224
                        )
                    ])
  return Compose([      # 테스트용 데이터일 경우에는 224X224로 resize만 수행합니다. 
                Resize(
                    width=224,
                    height=224
                    )
                ])

# %%
from google.colab import drive
drive.mount('/content/drive')
dir_path = "/content/drive/MyDrive/AIFFEL/GoingDeeper_CV/GD-10/semantic_segmentation/data/training"

augmentation_train = build_augmentation()
augmentation_test = build_augmentation(is_train=False)
input_images = glob(os.path.join(dir_path, "image_2", "*.png"))

# 훈련 데이터셋에서 5개만 가져와 augmentation을 적용해 봅시다.  
plt.figure(figsize=(12, 20))
for i in range(5):
    image = imread(input_images[i]) 
    image_data = {"image":image}
    resized = augmentation_test(**image_data)
    processed = augmentation_train(**image_data)
    plt.subplot(5, 2, 2*i+1)
    plt.imshow(resized["image"])  # 왼쪽이 원본이미지
    plt.subplot(5, 2, 2*i+2)
    plt.imshow(processed["image"])  # 오른쪽이 augment된 이미지
  
plt.show()
# Out:
# Mounted at /content/drive

# %%
class KittiGenerator(tf.keras.utils.Sequence):
  '''
  KittiGenerator는 tf.keras.utils.Sequence를 상속받습니다.
  우리가 KittiDataset을 원하는 방식으로 preprocess하기 위해서 Sequnce를 커스텀해 사용합니다.
  '''
  def __init__(self, 
               dir_path,
               batch_size=16,
               img_size=(224, 224, 3),
               output_size=(224, 224),
               is_train=True,
               augmentation=None):
    '''
    dir_path: dataset의 directory path입니다.
    batch_size: batch_size입니다.
    img_size: preprocess에 사용할 입력이미지의 크기입니다.
    output_size: ground_truth를 만들어주기 위한 크기입니다.
    is_train: 이 Generator가 학습용인지 테스트용인지 구분합니다.
    augmentation: 적용하길 원하는 augmentation 함수를 인자로 받습니다.
    '''
    self.dir_path = dir_path
    self.batch_size = batch_size
    self.is_train = is_train
    self.dir_path = dir_path
    self.augmentation = augmentation
    self.img_size = img_size
    self.output_size = output_size

    # load_dataset()을 통해서 kitti dataset의 directory path에서 라벨과 이미지를 확인합니다.
    self.data = self.load_dataset()

  def load_dataset(self):
    # kitti dataset에서 필요한 정보(이미지 경로 및 라벨)를 directory에서 확인하고 로드하는 함수입니다.
    # 이때 is_train에 따라 test set을 분리해서 load하도록 해야합니다.
    input_images = glob(os.path.join(self.dir_path, "image_2", "*.png"))
    label_images = glob(os.path.join(self.dir_path, "semantic", "*.png"))
    input_images.sort()
    label_images.sort()
    assert len(input_images) == len(label_images)
    data = [ _ for _ in zip(input_images, label_images)]

    if self.is_train:
      return data[:-30]
    return data[-30:]
    
  def __len__(self):
    # Generator의 length로서 전체 dataset을 batch_size로 나누고 소숫점 첫째자리에서 올림한 값을 반환합니다.
    return math.ceil(len(self.data) / self.batch_size)

  def __getitem__(self, index):
    # 입력과 출력을 만듭니다.
    # 입력은 resize및 augmentation이 적용된 input image이고 
    # 출력은 semantic label입니다.
    batch_data = self.data[
                           index*self.batch_size:
                           (index + 1)*self.batch_size
                           ]
    inputs = np.zeros([self.batch_size, *self.img_size])
    outputs = np.zeros([self.batch_size, *self.output_size])
        
    for i, data in enumerate(batch_data):
      input_img_path, output_path = data
      _input = imread(input_img_path)
      _output = imread(output_path)
      _output = (_output==7).astype(np.uint8)*1
      data = {
          "image": _input,
          "mask": _output,
          }
      augmented = self.augmentation(**data)
      inputs[i] = augmented["image"]/255
      outputs[i] = augmented["mask"]
      return inputs, outputs

  def on_epoch_end(self):
    # 한 epoch가 끝나면 실행되는 함수입니다. 학습중인 경우에 순서를 random shuffle하도록 적용한 것을 볼 수 있습니다.
    self.indexes = np.arange(len(self.data))
    if self.is_train == True :
      np.random.shuffle(self.indexes)
      return self.indexes

# %%
augmentation = build_augmentation()
test_preproc = build_augmentation(is_train=False)
        
train_generator = KittiGenerator(
    dir_path, 
    augmentation=augmentation,
)

test_generator = KittiGenerator(
    dir_path, 
    augmentation=test_preproc,
    is_train=False
)

# %%
def build_model(input_shape=(224, 224, 3)):
  inputs = Input(input_shape)
	
  #Contracting Path
  conv1 = Conv2D(64, 3, activation='relu', padding='same',kernel_initializer='he_normal')(inputs)
  conv1 = Conv2D(64, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv1)
  pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
  conv2 = Conv2D(128, 3, activation='relu', padding='same',kernel_initializer='he_normal')(pool1)
  conv2 = Conv2D(128, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv2)
  pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
  conv3 = Conv2D(256, 3, activation='relu', padding='same',kernel_initializer='he_normal')(pool2)
  conv3 = Conv2D(256, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv3)
  pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
  conv4 = Conv2D(512, 3, activation='relu', padding='same',kernel_initializer='he_normal')(pool3)
  conv4 = Conv2D(512, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv4)
  drop4 = Dropout(0.5)(conv4)
  pool4 = MaxPooling2D(pool_size=(2, 2))(drop4)
  
  conv5 = Conv2D(1024, 3, activation='relu', padding='same',kernel_initializer='he_normal')(pool4)  
  conv5 = Conv2D(1024, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv5)
  
  #Expanding Path
  drop5 = Dropout(0.5)(conv5)
  up6 = Conv2DTranspose(512, 2, activation='relu', strides=(2,2), kernel_initializer='he_normal')(drop5)
  merge6 = concatenate([drop4,up6], axis = 3)
  conv6 = Conv2D(512, 3, activation='relu', padding='same',kernel_initializer='he_normal')(merge6)
  conv6 = Conv2D(512, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv6)
  up7 = Conv2DTranspose(256, 2, activation='relu', strides=(2,2), kernel_initializer='he_normal')(conv6)
  merge7 = concatenate([conv3,up7], axis = 3)
  conv7 = Conv2D(256, 3, activation='relu', padding='same',kernel_initializer='he_normal')(merge7)
  conv7 = Conv2D(256, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv7)
  up8 = Conv2DTranspose(128, 2, activation='relu', strides=(2,2), kernel_initializer='he_normal')(conv7)
  merge8 = concatenate([conv2,up8], axis = 3)
  conv8 = Conv2D(128, 3, activation='relu', padding='same',kernel_initializer='he_normal')(merge8)
  conv8 = Conv2D(128, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv8)
  up9 = Conv2DTranspose(64, 2, activation='relu', strides=(2,2), kernel_initializer='he_normal')(conv8)
  merge9 = concatenate([conv1,up9], axis = 3)
  conv9 = Conv2D(64, 3, activation='relu', padding='same',kernel_initializer='he_normal')(merge9)
  conv9 = Conv2D(64, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv9)  
  conv9 = Conv2D(2, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv9)     
  conv10 = Conv2D(1, 1, activation='sigmoid')(conv9)

  model = Model(inputs = inputs, outputs = conv10)
  return model

# %%
unet = build_model()
unet.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d_52 (Conv2D)             (None, 224, 224, 64  1792        ['input_3[0][0]']
#                                 )
#
#  conv2d_53 (Conv2D)             (None, 224, 224, 64  36928       ['conv2d_52[0][0]']
#                                 )
#
#  max_pooling2d_14 (MaxPooling2D  (None, 112, 112, 64  0          ['conv2d_53[0][0]']
#  )                              )
#
#  conv2d_54 (Conv2D)             (None, 112, 112, 12  73856       ['max_pooling2d_14[0][0]']
#                                 8)
#
#  conv2d_55 (Conv2D)             (None, 112, 112, 12  147584      ['conv2d_54[0][0]']
#                                 8)
#
#  max_pooling2d_15 (MaxPooling2D  (None, 56, 56, 128)  0          ['conv2d_55[0][0]']
#  )
#
#  conv2d_56 (Conv2D)             (None, 56, 56, 256)  295168      ['max_pooling2d_15[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 56, 56, 256)  590080      ['conv2d_56[0][0]']
#
#  max_pooling2d_16 (MaxPooling2D  (None, 28, 28, 256)  0          ['conv2d_57[0][0]']
#  )
#
#  conv2d_58 (Conv2D)             (None, 28, 28, 512)  1180160     ['max_pooling2d_16[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 28, 28, 512)  2359808     ['conv2d_58[0][0]']
#
#  dropout_4 (Dropout)            (None, 28, 28, 512)  0           ['conv2d_59[0][0]']
#
#  max_pooling2d_17 (MaxPooling2D  (None, 14, 14, 512)  0          ['dropout_4[0][0]']
#  )
#
#  conv2d_60 (Conv2D)             (None, 14, 14, 1024  4719616     ['max_pooling2d_17[0][0]']
#                                 )
#
#  conv2d_61 (Conv2D)             (None, 14, 14, 1024  9438208     ['conv2d_60[0][0]']
#                                 )
#
#  dropout_5 (Dropout)            (None, 14, 14, 1024  0           ['conv2d_61[0][0]']
#                                 )
#
#  conv2d_transpose_8 (Conv2DTran  (None, 28, 28, 512)  2097664    ['dropout_5[0][0]']
#  spose)
#
#  concatenate_8 (Concatenate)    (None, 28, 28, 1024  0           ['dropout_4[0][0]',
#                                 )                                 'conv2d_transpose_8[0][0]']
#
#  conv2d_62 (Conv2D)             (None, 28, 28, 512)  4719104     ['concatenate_8[0][0]']
#
#  conv2d_63 (Conv2D)             (None, 28, 28, 512)  2359808     ['conv2d_62[0][0]']
#
#  conv2d_transpose_9 (Conv2DTran  (None, 56, 56, 256)  524544     ['conv2d_63[0][0]']
#  spose)
#
#  concatenate_9 (Concatenate)    (None, 56, 56, 512)  0           ['conv2d_57[0][0]',
#                                                                   'conv2d_transpose_9[0][0]']
#
#  conv2d_64 (Conv2D)             (None, 56, 56, 256)  1179904     ['concatenate_9[0][0]']
#
#  conv2d_65 (Conv2D)             (None, 56, 56, 256)  590080      ['conv2d_64[0][0]']
#
#  conv2d_transpose_10 (Conv2DTra  (None, 112, 112, 12  131200     ['conv2d_65[0][0]']
#  nspose)                        8)
#
#  concatenate_10 (Concatenate)   (None, 112, 112, 25  0           ['conv2d_55[0][0]',
#                                 6)                                'conv2d_transpose_10[0][0]']
#
#  conv2d_66 (Conv2D)             (None, 112, 112, 12  295040      ['concatenate_10[0][0]']
#                                 8)
#
#  conv2d_67 (Conv2D)             (None, 112, 112, 12  147584      ['conv2d_66[0][0]']
#                                 8)
#
#  conv2d_transpose_11 (Conv2DTra  (None, 224, 224, 64  32832      ['conv2d_67[0][0]']
#  nspose)                        )
#
#  concatenate_11 (Concatenate)   (None, 224, 224, 12  0           ['conv2d_53[0][0]',
#                                 8)                                'conv2d_transpose_11[0][0]']
#
#  conv2d_68 (Conv2D)             (None, 224, 224, 64  73792       ['concatenate_11[0][0]']
#                                 )
#
#  conv2d_69 (Conv2D)             (None, 224, 224, 64  36928       ['conv2d_68[0][0]']
#                                 )
#
#  conv2d_70 (Conv2D)             (None, 224, 224, 2)  1154        ['conv2d_69[0][0]']
#
#  conv2d_71 (Conv2D)             (None, 224, 224, 1)  3           ['conv2d_70[0][0]']
#
# ==================================================================================================
# Total params: 31,032,837
# Trainable params: 31,032,837
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
unet_path = "/content/drive/MyDrive/AIFFEL/GoingDeeper_CV/GD-10/semantic_segmentation/seg_model_unet.h5"

unet = build_model()
unet.compile(optimizer = Adam(1e-4), loss = 'binary_crossentropy')
unet.fit(
     train_generator,
     validation_data=test_generator,
     steps_per_epoch=len(train_generator),
     epochs=100,
 )

unet.save(unet_path)  #학습한 모델을 저장해 주세요.
# Out:
# Epoch 1/100
# 11/11 [==============================] - 19s 769ms/step - loss: 0.6875 - val_loss: 0.6762
# Epoch 2/100
# 11/11 [==============================] - 7s 635ms/step - loss: 0.5409 - val_loss: 0.0807
# Epoch 3/100
# 11/11 [==============================] - 7s 623ms/step - loss: 0.0347 - val_loss: 0.0343
# Epoch 4/100
# 11/11 [==============================] - 7s 623ms/step - loss: 0.0358 - val_loss: 0.0361
# Epoch 5/100
# 11/11 [==============================] - 7s 625ms/step - loss: 0.0385 - val_loss: 0.0338
# Epoch 6/100
# 11/11 [==============================] - 7s 626ms/step - loss: 0.0302 - val_loss: 0.0294
# Epoch 7/100
# 11/11 [==============================] - 7s 625ms/step - loss: 0.0256 - val_loss: 0.0282
# Epoch 8/100
# 11/11 [==============================] - 7s 620ms/step - loss: 0.0335 - val_loss: 0.0298
# Epoch 9/100
# 11/11 [==============================] - 7s 617ms/step - loss: 0.0290 - val_loss: 0.0508
# Epoch 10/100
# 11/11 [==============================] - 7s 616ms/step - loss: 0.0401 - val_loss: 0.0334
# Epoch 11/100
# 11/11 [==============================] - 7s 616ms/step - loss: 0.1028 - val_loss: 0.2815
# Epoch 12/100
# 11/11 [==============================] - 7s 614ms/step - loss: 0.2219 - val_loss: 0.2819
# Epoch 13/100
# 11/11 [==============================] - 7s 613ms/step - loss: 0.2212 - val_loss: 0.2819
# Epoch 14/100
# 11/11 [==============================] - 7s 615ms/step - loss: 0.2629 - val_loss: 0.2819
# Epoch 15/100
# 11/11 [==============================] - 7s 614ms/step - loss: 0.2335 - val_loss: 0.2819
# Epoch 16/100
# 11/11 [==============================] - 7s 616ms/step - loss: 0.2053 - val_loss: 0.2819
# Epoch 17/100
# 11/11 [==============================] - 7s 618ms/step - loss: 0.2553 - val_loss: 0.2819
# Epoch 18/100
# 11/11 [==============================] - 7s 619ms/step - loss: 0.2017 - val_loss: 0.2819
# Epoch 19/100
# 11/11 [==============================] - 7s 620ms/step - loss: 0.2207 - val_loss: 0.2819
# Epoch 20/100
# 11/11 [==============================] - 7s 618ms/step - loss: 0.2144 - val_loss: 0.2819
# Epoch 21/100
# 11/11 [==============================] - 7s 617ms/step - loss: 0.2605 - val_loss: 0.2818
# Epoch 22/100
# 11/11 [==============================] - 7s 616ms/step - loss: 0.2100 - val_loss: 0.2818
# Epoch 23/100
# 11/11 [==============================] - 7s 616ms/step - loss: 0.2355 - val_loss: 0.2817
# Epoch 24/100
# 11/11 [==============================] - 7s 616ms/step - loss: 0.2556 - val_loss: 0.2807
# Epoch 25/100
# 11/11 [==============================] - 7s 616ms/step - loss: 0.2239 - val_loss: 0.0258
# Epoch 26/100
# 11/11 [==============================] - 7s 623ms/step - loss: 0.0327 - val_loss: 0.0248
# Epoch 27/100
# 11/11 [==============================] - 7s 631ms/step - loss: 0.0520 - val_loss: 0.0318
# Epoch 28/100
# 11/11 [==============================] - 7s 622ms/step - loss: 0.0268 - val_loss: 0.1244
# Epoch 29/100
# 11/11 [==============================] - 7s 620ms/step - loss: 0.0248 - val_loss: 0.0254
# Epoch 30/100
# 11/11 [==============================] - 7s 624ms/step - loss: 0.0226 - val_loss: 0.0227
# Epoch 31/100
# 11/11 [==============================] - 7s 623ms/step - loss: 0.0231 - val_loss: 0.0209
# Epoch 32/100
# 11/11 [==============================] - 7s 623ms/step - loss: 0.0241 - val_loss: 0.0236
# Epoch 33/100
# 11/11 [==============================] - 7s 622ms/step - loss: 0.0204 - val_loss: 0.0207
# Epoch 34/100
# 11/11 [==============================] - 7s 621ms/step - loss: 0.0219 - val_loss: 0.0214
# Epoch 35/100
# 11/11 [==============================] - 7s 623ms/step - loss: 0.0204 - val_loss: 0.0207
# Epoch 36/100
# 11/11 [==============================] - 7s 622ms/step - loss: 0.0179 - val_loss: 0.0197
# Epoch 37/100
# 11/11 [==============================] - 7s 621ms/step - loss: 0.0171 - val_loss: 0.0196
# Epoch 38/100
# 11/11 [==============================] - 7s 620ms/step - loss: 0.0188 - val_loss: 0.0198
# Epoch 39/100
# 11/11 [==============================] - 7s 621ms/step - loss: 0.0189 - val_loss: 0.0204
# Epoch 40/100
# 11/11 [==============================] - 7s 621ms/step - loss: 0.0185 - val_loss: 0.0218
# Epoch 41/100
# 11/11 [==============================] - 7s 620ms/step - loss: 0.0180 - val_loss: 0.0194
# Epoch 42/100
# 11/11 [==============================] - 7s 620ms/step - loss: 0.0172 - val_loss: 0.0195
# Epoch 43/100
# 11/11 [==============================] - 7s 620ms/step - loss: 0.0175 - val_loss: 0.0196
# Epoch 44/100
# 11/11 [==============================] - 7s 619ms/step - loss: 0.0179 - val_loss: 0.0200
# Epoch 45/100
# 11/11 [==============================] - 7s 618ms/step - loss: 0.0191 - val_loss: 0.0229
# Epoch 46/100
# 11/11 [==============================] - 7s 619ms/step - loss: 0.0244 - val_loss: 0.0218
# Epoch 47/100
# 11/11 [==============================] - 7s 621ms/step - loss: 0.0209 - val_loss: 0.0209
# Epoch 48/100
# 11/11 [==============================] - 7s 621ms/step - loss: 0.0182 - val_loss: 0.0216
# Epoch 49/100
# 11/11 [==============================] - 7s 621ms/step - loss: 0.0203 - val_loss: 0.0226
# Epoch 50/100
# 11/11 [==============================] - 7s 619ms/step - loss: 0.0207 - val_loss: 0.0217
# Epoch 51/100
# 11/11 [==============================] - 7s 619ms/step - loss: 0.0168 - val_loss: 0.0209
# Epoch 52/100
# 11/11 [==============================] - 7s 620ms/step - loss: 0.0222 - val_loss: 0.0227
# Epoch 53/100
# 11/11 [==============================] - 7s 623ms/step - loss: 0.0216 - val_loss: 0.0243
# Epoch 54/100
# 11/11 [==============================] - 7s 619ms/step - loss: 0.0183 - val_loss: 0.0220
# Epoch 55/100
# 11/11 [==============================] - 7s 615ms/step - loss: 0.0158 - val_loss: 0.0210
# Epoch 56/100
# 11/11 [==============================] - 7s 615ms/step - loss: 0.0158 - val_loss: 0.0220
# Epoch 57/100
# 11/11 [==============================] - 7s 615ms/step - loss: 0.0144 - val_loss: 0.0208
# Epoch 58/100
# 11/11 [==============================] - 7s 615ms/step - loss: 0.0170 - val_loss: 0.0218
# Epoch 59/100
# 11/11 [==============================] - 7s 612ms/step - loss: 0.0154 - val_loss: 0.0205
# Epoch 60/100
# 11/11 [==============================] - 7s 613ms/step - loss: 0.0157 - val_loss: 0.0231
# Epoch 61/100
# 11/11 [==============================] - 7s 613ms/step - loss: 0.0176 - val_loss: 0.0205
# Epoch 62/100
# 11/11 [==============================] - 7s 614ms/step - loss: 0.0158 - val_loss: 0.0203
# Epoch 63/100
# 11/11 [==============================] - 7s 613ms/step - loss: 0.0193 - val_loss: 0.0209
# Epoch 64/100
# 11/11 [==============================] - 7s 612ms/step - loss: 0.0228 - val_loss: 0.0259
# Epoch 65/100
# 11/11 [==============================] - 7s 613ms/step - loss: 0.0310 - val_loss: 0.0257
# Epoch 66/100
# 11/11 [==============================] - 7s 622ms/step - loss: 0.0240 - val_loss: 0.0240
# Epoch 67/100
# 11/11 [==============================] - 7s 622ms/step - loss: 0.0227 - val_loss: 0.0249
# Epoch 68/100
# 11/11 [==============================] - 7s 620ms/step - loss: 0.0233 - val_loss: 0.0215
# Epoch 69/100
# 11/11 [==============================] - 7s 617ms/step - loss: 0.0222 - val_loss: 0.0240
# Epoch 70/100
# 11/11 [==============================] - 7s 619ms/step - loss: 0.0225 - val_loss: 0.0229
# Epoch 71/100
# 11/11 [==============================] - 7s 618ms/step - loss: 0.0203 - val_loss: 0.0222
# Epoch 72/100
# 11/11 [==============================] - 7s 617ms/step - loss: 0.0194 - val_loss: 0.0210
# Epoch 73/100
# 11/11 [==============================] - 7s 617ms/step - loss: 0.0212 - val_loss: 0.0211
# Epoch 74/100
# 11/11 [==============================] - 7s 618ms/step - loss: 0.0167 - val_loss: 0.0218
# Epoch 75/100
# 11/11 [==============================] - 7s 617ms/step - loss: 0.0180 - val_loss: 0.0205
# Epoch 76/100
# 11/11 [==============================] - 7s 617ms/step - loss: 0.0146 - val_loss: 0.0270
# Epoch 77/100
# 11/11 [==============================] - 7s 617ms/step - loss: 0.0169 - val_loss: 0.0210
# Epoch 78/100
# 11/11 [==============================] - 7s 616ms/step - loss: 0.0196 - val_loss: 0.0208
# Epoch 79/100
# 11/11 [==============================] - 7s 616ms/step - loss: 0.0189 - val_loss: 0.0247
# Epoch 80/100
# 11/11 [==============================] - 7s 615ms/step - loss: 0.0159 - val_loss: 0.0218
# Epoch 81/100
# 11/11 [==============================] - 7s 617ms/step - loss: 0.0148 - val_loss: 0.0207
# Epoch 82/100
# 11/11 [==============================] - 7s 616ms/step - loss: 0.0142 - val_loss: 0.0274
# Epoch 83/100
# 11/11 [==============================] - 7s 616ms/step - loss: 0.0152 - val_loss: 0.0196
# Epoch 84/100
# 11/11 [==============================] - 7s 618ms/step - loss: 0.0158 - val_loss: 0.0200
# Epoch 85/100
# 11/11 [==============================] - 7s 617ms/step - loss: 0.0140 - val_loss: 0.0200
# Epoch 86/100
# 11/11 [==============================] - 7s 615ms/step - loss: 0.0152 - val_loss: 0.0331
# Epoch 87/100
# 11/11 [==============================] - 7s 616ms/step - loss: 0.0167 - val_loss: 0.0205
# Epoch 88/100
# 11/11 [==============================] - 7s 616ms/step - loss: 0.0143 - val_loss: 0.0258
# Epoch 89/100
# 11/11 [==============================] - 7s 617ms/step - loss: 0.0181 - val_loss: 0.0187
# Epoch 90/100
# 11/11 [==============================] - 7s 615ms/step - loss: 0.0126 - val_loss: 0.0201
# Epoch 91/100
# 11/11 [==============================] - 7s 616ms/step - loss: 0.0134 - val_loss: 0.0262
# Epoch 92/100
# 11/11 [==============================] - 7s 618ms/step - loss: 0.0121 - val_loss: 0.0183
# Epoch 93/100
# 11/11 [==============================] - 7s 616ms/step - loss: 0.0121 - val_loss: 0.0187
# Epoch 94/100
# 11/11 [==============================] - 7s 617ms/step - loss: 0.0110 - val_loss: 0.0213
# Epoch 95/100
# 11/11 [==============================] - 7s 617ms/step - loss: 0.0174 - val_loss: 0.0223
# Epoch 96/100
# 11/11 [==============================] - 7s 615ms/step - loss: 0.0139 - val_loss: 0.0195
# Epoch 97/100
# 11/11 [==============================] - 7s 616ms/step - loss: 0.0167 - val_loss: 0.0197
# Epoch 98/100
# 11/11 [==============================] - 7s 617ms/step - loss: 0.0129 - val_loss: 0.0189
# Epoch 99/100
# 11/11 [==============================] - 7s 618ms/step - loss: 0.0152 - val_loss: 0.0191
# Epoch 100/100
# 11/11 [==============================] - 7s 616ms/step - loss: 0.0120 - val_loss: 0.0186

# %%
# 미리 준비한 모델을 불러오려면 아래 주석을 해제하세요
dir_path = "/content/drive/MyDrive/AIFFEL/GoingDeeper_CV/GD-10/semantic_segmentation/data/training/seg_model_unet.h5"
#model_path = dir_path + '/seg_model_unet.h5' 

model = tf.keras.models.load_model(dir_path)

# %%
def build_unet_plus(input_shape=(224, 224, 3)):
    model = None
    # TODO: input_shape에 따라 U-Net을 만들어주세요
    # 이때 model은 fully convolutional해야 합니다.
    inputs = Input(input_shape)

    #Contracting Path
    conv1 = Conv2D(64, 3, activation='relu', padding='same',kernel_initializer='he_normal')(inputs)
    conv1 = Conv2D(64, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    
    conv2 = Conv2D(128, 3, activation='relu', padding='same',kernel_initializer='he_normal')(pool1)
    conv2 = Conv2D(128, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    
    
#     up6 = Conv2DTranspose(512, 2, activation='relu', strides=(2,2), kernel_initializer='he_normal')(drop5)
    
    conv1_2 = Conv2DTranspose(64, (2,2), strides=2, name='up1_2', padding='same')(conv2)
    conv1_2 = concatenate([conv1_2, conv1], name='merge1_2', axis=3)
    conv1_2 = Conv2D(64, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv1_2)
    conv1_2 = Conv2D(64, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv1_2)
    pool1_2 = MaxPooling2D(pool_size=(2, 2))(conv1_2)
    
    conv3 = Conv2D(256, 3, activation='relu', padding='same',kernel_initializer='he_normal')(pool2)
    conv3 = Conv2D(256, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    
    conv2_2 = Conv2DTranspose(128, (2,2), strides=2, name='up2_2', padding='same')(conv3)
    conv2_2 = concatenate([conv2_2, conv2], name='merge2_2', axis=3)
    conv2_2 = Conv2D(128, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv2_2)
    conv2_2 = Conv2D(128, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv2_2)
    pool2_2 = MaxPooling2D(pool_size=(2, 2))(conv2_2)
    
    conv1_3 = Conv2DTranspose(64, (2,2), strides=2, name='up1_3', padding='same')(conv2_2)
    conv1_3 = concatenate([conv1_3, conv1, conv1_2], name='merge1_3', axis=3)
    conv1_3 = Conv2D(64, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv1_3)
    conv1_3 = Conv2D(64, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv1_3)
    pool1_3 = MaxPooling2D(pool_size=(2, 2))(conv1_3)
    
    conv4 = Conv2D(512, 3, activation='relu', padding='same',kernel_initializer='he_normal')(pool3)
    conv4 = Conv2D(512, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv4)
    drop4 = Dropout(0.5)(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(drop4)

    conv3_2 = Conv2DTranspose(256, (2,2), strides=2, name='up3_2', padding='same')(conv4)
    conv3_2 = concatenate([conv3_2, conv3], name='merge3_2', axis=3)
    conv3_2 = Conv2D(256, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv3_2)
    conv3_2 = Conv2D(256, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv3_2)
    pool3_2 = MaxPooling2D(pool_size=(2, 2))(conv3_2)

    conv2_3 = Conv2DTranspose(128, (2,2), strides=2, name='up2_3', padding='same')(conv3_2)
    conv2_3 = concatenate([conv2_3, conv2, conv2_2], name='merge2_3', axis=3)
    conv2_3 = Conv2D(128, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv2_3)
    conv2_3 = Conv2D(128, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv2_3)
    pool2_3 = MaxPooling2D(pool_size=(2, 2))(conv2_3)

    conv1_4 = Conv2DTranspose(64, (2,2), strides=2, name='up1_4', padding='same')(conv2_3)
    conv1_4 = concatenate([conv1_4, conv1, conv1_2, conv1_3], name='merge1_4', axis=3)
    conv1_4 = Conv2D(64, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv1_4)
    conv1_4 = Conv2D(64, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv1_4)
    pool1_4 = MaxPooling2D(pool_size=(2, 2))(conv1_4)

    conv5 = Conv2D(1024, 3, activation='relu', padding='same',kernel_initializer='he_normal')(pool4)  
    conv5 = Conv2D(1024, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv5)

    
    #Expanding Path
    drop5 = Dropout(0.5)(conv5)
    
    up6 = Conv2DTranspose(512, 2, activation='relu', strides=(2,2), kernel_initializer='he_normal')(drop5)
    merge6 = concatenate([drop4,up6], axis = 3)
    conv6 = Conv2D(512, 3, activation='relu', padding='same',kernel_initializer='he_normal')(merge6)
    conv6 = Conv2D(512, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv6)
    
    up7 = Conv2DTranspose(256, 2, activation='relu', strides=(2,2), kernel_initializer='he_normal')(conv6)
    merge7 = concatenate([conv3, conv3_2 ,up7], axis = 3)
    conv7 = Conv2D(256, 3, activation='relu', padding='same',kernel_initializer='he_normal')(merge7)
    conv7 = Conv2D(256, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv7)
    
    up8 = Conv2DTranspose(128, 2, activation='relu', strides=(2,2), kernel_initializer='he_normal')(conv7)
    merge8 = concatenate([conv2, conv2_2, conv2_3,up8], axis = 3)
    conv8 = Conv2D(128, 3, activation='relu', padding='same',kernel_initializer='he_normal')(merge8)
    conv8 = Conv2D(128, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv8)
    
    up9 = Conv2DTranspose(64, 2, activation='relu', strides=(2,2), kernel_initializer='he_normal')(conv8)
    merge9 = concatenate([conv1,conv1_2, conv1_3, conv1_4, up9], axis = 3)
    conv9 = Conv2D(64, 3, activation='relu', padding='same',kernel_initializer='he_normal')(merge9)
    conv9 = Conv2D(64, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv9)  
    conv9 = Conv2D(2, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv9)     
    
    conv10 = Conv2D(1, 1, activation='sigmoid')(conv9)

    model = Model(inputs = inputs, outputs = conv10)
    return model

# %%
unet_plus = build_unet_plus()
unet_plus.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d_92 (Conv2D)             (None, 224, 224, 64  1792        ['input_5[0][0]']
#                                 )
#
#  conv2d_93 (Conv2D)             (None, 224, 224, 64  36928       ['conv2d_92[0][0]']
#                                 )
#
#  max_pooling2d_22 (MaxPooling2D  (None, 112, 112, 64  0          ['conv2d_93[0][0]']
#  )                              )
#
#  conv2d_94 (Conv2D)             (None, 112, 112, 12  73856       ['max_pooling2d_22[0][0]']
#                                 8)
#
#  conv2d_95 (Conv2D)             (None, 112, 112, 12  147584      ['conv2d_94[0][0]']
#                                 8)
#
#  max_pooling2d_23 (MaxPooling2D  (None, 56, 56, 128)  0          ['conv2d_95[0][0]']
#  )
#
#  conv2d_98 (Conv2D)             (None, 56, 56, 256)  295168      ['max_pooling2d_23[0][0]']
#
#  conv2d_99 (Conv2D)             (None, 56, 56, 256)  590080      ['conv2d_98[0][0]']
#
#  max_pooling2d_25 (MaxPooling2D  (None, 28, 28, 256)  0          ['conv2d_99[0][0]']
#  )
#
#  conv2d_104 (Conv2D)            (None, 28, 28, 512)  1180160     ['max_pooling2d_25[0][0]']
#
#  conv2d_105 (Conv2D)            (None, 28, 28, 512)  2359808     ['conv2d_104[0][0]']
#
#  dropout_8 (Dropout)            (None, 28, 28, 512)  0           ['conv2d_105[0][0]']
#
#  max_pooling2d_28 (MaxPooling2D  (None, 14, 14, 512)  0          ['dropout_8[0][0]']
#  )
#
#  conv2d_112 (Conv2D)            (None, 14, 14, 1024  4719616     ['max_pooling2d_28[0][0]']
#                                 )
#
#  conv2d_113 (Conv2D)            (None, 14, 14, 1024  9438208     ['conv2d_112[0][0]']
#                                 )
#
#  dropout_9 (Dropout)            (None, 14, 14, 1024  0           ['conv2d_113[0][0]']
#                                 )
#
#  conv2d_transpose_16 (Conv2DTra  (None, 28, 28, 512)  2097664    ['dropout_9[0][0]']
#  nspose)
#
#  up3_2 (Conv2DTranspose)        (None, 56, 56, 256)  524544      ['conv2d_105[0][0]']
#
#  concatenate_16 (Concatenate)   (None, 28, 28, 1024  0           ['dropout_8[0][0]',
#                                 )                                 'conv2d_transpose_16[0][0]']
#
#  up2_2 (Conv2DTranspose)        (None, 112, 112, 12  131200      ['conv2d_99[0][0]']
#                                 8)
#
#  merge3_2 (Concatenate)         (None, 56, 56, 512)  0           ['up3_2[0][0]',
#                                                                   'conv2d_99[0][0]']
#
#  conv2d_114 (Conv2D)            (None, 28, 28, 512)  4719104     ['concatenate_16[0][0]']
#
#  up1_2 (Conv2DTranspose)        (None, 224, 224, 64  32832       ['conv2d_95[0][0]']
#                                 )
#
#  merge2_2 (Concatenate)         (None, 112, 112, 25  0           ['up2_2[0][0]',
#                                 6)                                'conv2d_95[0][0]']
#
#  conv2d_106 (Conv2D)            (None, 56, 56, 256)  1179904     ['merge3_2[0][0]']
#
#  conv2d_115 (Conv2D)            (None, 28, 28, 512)  2359808     ['conv2d_114[0][0]']
#
#  merge1_2 (Concatenate)         (None, 224, 224, 12  0           ['up1_2[0][0]',
#                                 8)                                'conv2d_93[0][0]']
#
#  conv2d_100 (Conv2D)            (None, 112, 112, 12  295040      ['merge2_2[0][0]']
#                                 8)
#
#  conv2d_107 (Conv2D)            (None, 56, 56, 256)  590080      ['conv2d_106[0][0]']
#
#  conv2d_transpose_17 (Conv2DTra  (None, 56, 56, 256)  524544     ['conv2d_115[0][0]']
#  nspose)
#
#  conv2d_96 (Conv2D)             (None, 224, 224, 64  73792       ['merge1_2[0][0]']
#                                 )
#
#  conv2d_101 (Conv2D)            (None, 112, 112, 12  147584      ['conv2d_100[0][0]']
#                                 8)
#
#  up2_3 (Conv2DTranspose)        (None, 112, 112, 12  131200      ['conv2d_107[0][0]']
#                                 8)
#
#  concatenate_17 (Concatenate)   (None, 56, 56, 768)  0           ['conv2d_99[0][0]',
#                                                                   'conv2d_107[0][0]',
#                                                                   'conv2d_transpose_17[0][0]']
#
#  conv2d_97 (Conv2D)             (None, 224, 224, 64  36928       ['conv2d_96[0][0]']
#                                 )
#
#  up1_3 (Conv2DTranspose)        (None, 224, 224, 64  32832       ['conv2d_101[0][0]']
#                                 )
#
#  merge2_3 (Concatenate)         (None, 112, 112, 38  0           ['up2_3[0][0]',
#                                 4)                                'conv2d_95[0][0]',
#                                                                   'conv2d_101[0][0]']
#
#  conv2d_116 (Conv2D)            (None, 56, 56, 256)  1769728     ['concatenate_17[0][0]']
#
#  merge1_3 (Concatenate)         (None, 224, 224, 19  0           ['up1_3[0][0]',
#                                 2)                                'conv2d_93[0][0]',
#                                                                   'conv2d_97[0][0]']
#
#  conv2d_108 (Conv2D)            (None, 112, 112, 12  442496      ['merge2_3[0][0]']
#                                 8)
#
#  conv2d_117 (Conv2D)            (None, 56, 56, 256)  590080      ['conv2d_116[0][0]']
#
#  conv2d_102 (Conv2D)            (None, 224, 224, 64  110656      ['merge1_3[0][0]']
#                                 )
#
#  conv2d_109 (Conv2D)            (None, 112, 112, 12  147584      ['conv2d_108[0][0]']
#                                 8)
#
#  conv2d_transpose_18 (Conv2DTra  (None, 112, 112, 12  131200     ['conv2d_117[0][0]']
#  nspose)                        8)
#
#  conv2d_103 (Conv2D)            (None, 224, 224, 64  36928       ['conv2d_102[0][0]']
#                                 )
#
#  up1_4 (Conv2DTranspose)        (None, 224, 224, 64  32832       ['conv2d_109[0][0]']
#                                 )
#
#  concatenate_18 (Concatenate)   (None, 112, 112, 51  0           ['conv2d_95[0][0]',
#                                 2)                                'conv2d_101[0][0]',
#                                                                   'conv2d_109[0][0]',
#                                                                   'conv2d_transpose_18[0][0]']
#
#  merge1_4 (Concatenate)         (None, 224, 224, 25  0           ['up1_4[0][0]',
#                                 6)                                'conv2d_93[0][0]',
#                                                                   'conv2d_97[0][0]',
#                                                                   'conv2d_103[0][0]']
#
#  conv2d_118 (Conv2D)            (None, 112, 112, 12  589952      ['concatenate_18[0][0]']
#                                 8)
#
#  conv2d_110 (Conv2D)            (None, 224, 224, 64  147520      ['merge1_4[0][0]']
#                                 )
#
#  conv2d_119 (Conv2D)            (None, 112, 112, 12  147584      ['conv2d_118[0][0]']
#                                 8)
#
#  conv2d_111 (Conv2D)            (None, 224, 224, 64  36928       ['conv2d_110[0][0]']
#                                 )
#
#  conv2d_transpose_19 (Conv2DTra  (None, 224, 224, 64  32832      ['conv2d_119[0][0]']
#  nspose)                        )
#
#  concatenate_19 (Concatenate)   (None, 224, 224, 32  0           ['conv2d_93[0][0]',
#                                 0)                                'conv2d_97[0][0]',
#                                                                   'conv2d_103[0][0]',
#                                                                   'conv2d_111[0][0]',
#                                                                   'conv2d_transpose_19[0][0]']
#
#  conv2d_120 (Conv2D)            (None, 224, 224, 64  184384      ['concatenate_19[0][0]']
#                                 )
#
#  conv2d_121 (Conv2D)            (None, 224, 224, 64  36928       ['conv2d_120[0][0]']
#                                 )
#
#  conv2d_122 (Conv2D)            (None, 224, 224, 2)  1154        ['conv2d_121[0][0]']
#
#  conv2d_123 (Conv2D)            (None, 224, 224, 1)  3           ['conv2d_122[0][0]']
#
# ==================================================================================================
# Total params: 36,159,045
# Trainable params: 36,159,045
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
unet_plus.compile(optimizer = Adam(1e-4), loss = 'binary_crossentropy')
unet_plus.fit_generator(
     generator=train_generator,
     validation_data=test_generator,
     steps_per_epoch=len(train_generator),
     epochs=100,
 )

unet_plus_path = "/content/drive/MyDrive/AIFFEL/GoingDeeper_CV/GD-10/semantic_segmentation/seg_model_unet_plus.h5"
unet_plus.save(unet_plus_path)  #학습한 모델을 저장해 주세요.
# Out:
# Epoch 1/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# 11/11 [==============================] - 30s 2s/step - loss: 0.6937 - val_loss: 0.6926
# Epoch 2/100
# 11/11 [==============================] - 19s 2s/step - loss: 0.6919 - val_loss: 0.6898
# Epoch 3/100
# 11/11 [==============================] - 19s 2s/step - loss: 0.6814 - val_loss: 0.6608
# Epoch 4/100
# 11/11 [==============================] - 19s 2s/step - loss: 0.6031 - val_loss: 0.3956
# Epoch 5/100
# 11/11 [==============================] - 19s 2s/step - loss: 0.1170 - val_loss: 0.0293
# Epoch 6/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0270 - val_loss: 0.0276
# Epoch 7/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0273 - val_loss: 0.0281
# Epoch 8/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0239 - val_loss: 0.0289
# Epoch 9/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0244 - val_loss: 0.0277
# Epoch 10/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0243 - val_loss: 0.0284
# Epoch 11/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0237 - val_loss: 0.0274
# Epoch 12/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0275 - val_loss: 0.0300
# Epoch 13/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0240 - val_loss: 0.0293
# Epoch 14/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0235 - val_loss: 0.0275
# Epoch 15/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0231 - val_loss: 0.0252
# Epoch 16/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0208 - val_loss: 0.0248
# Epoch 17/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0182 - val_loss: 0.0230
# Epoch 18/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0172 - val_loss: 0.0308
# Epoch 19/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0216 - val_loss: 0.0249
# Epoch 20/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0192 - val_loss: 0.0206
# Epoch 21/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0155 - val_loss: 0.0205
# Epoch 22/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0152 - val_loss: 0.0210
# Epoch 23/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0160 - val_loss: 0.0227
# Epoch 24/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0138 - val_loss: 0.0204
# Epoch 25/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0169 - val_loss: 0.0204
# Epoch 26/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0134 - val_loss: 0.0227
# Epoch 27/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0148 - val_loss: 0.0202
# Epoch 28/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0126 - val_loss: 0.0206
# Epoch 29/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0190 - val_loss: 0.0200
# Epoch 30/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0146 - val_loss: 0.0201
# Epoch 31/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0148 - val_loss: 0.0198
# Epoch 32/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0135 - val_loss: 0.0198
# Epoch 33/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0131 - val_loss: 0.0180
# Epoch 34/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0147 - val_loss: 0.0187
# Epoch 35/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0124 - val_loss: 0.0174
# Epoch 36/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0129 - val_loss: 0.0188
# Epoch 37/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0117 - val_loss: 0.0213
# Epoch 38/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0131 - val_loss: 0.0238
# Epoch 39/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0129 - val_loss: 0.0196
# Epoch 40/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0130 - val_loss: 0.0183
# Epoch 41/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0121 - val_loss: 0.0184
# Epoch 42/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0106 - val_loss: 0.0181
# Epoch 43/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0101 - val_loss: 0.0203
# Epoch 44/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0109 - val_loss: 0.0209
# Epoch 45/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0107 - val_loss: 0.0196
# Epoch 46/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0134 - val_loss: 0.0336
# Epoch 47/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0139 - val_loss: 0.0177
# Epoch 48/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0116 - val_loss: 0.0180
# Epoch 49/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0091 - val_loss: 0.0190
# Epoch 50/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0113 - val_loss: 0.0219
# Epoch 51/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0100 - val_loss: 0.0198
# Epoch 52/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0104 - val_loss: 0.0192
# Epoch 53/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0121 - val_loss: 0.0191
# Epoch 54/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0103 - val_loss: 0.0186
# Epoch 55/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0138 - val_loss: 0.0212
# Epoch 56/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0136 - val_loss: 0.0255
# Epoch 57/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0152 - val_loss: 0.0191
# Epoch 58/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0121 - val_loss: 0.0199
# Epoch 59/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0109 - val_loss: 0.0182
# Epoch 60/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0117 - val_loss: 0.0199
# Epoch 61/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0098 - val_loss: 0.0176
# Epoch 62/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0089 - val_loss: 0.0176
# Epoch 63/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0127 - val_loss: 0.0193
# Epoch 64/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0111 - val_loss: 0.0180
# Epoch 65/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0129 - val_loss: 0.0183
# Epoch 66/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0090 - val_loss: 0.0170
# Epoch 67/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0118 - val_loss: 0.0173
# Epoch 68/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0103 - val_loss: 0.0167
# Epoch 69/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0095 - val_loss: 0.0188
# Epoch 70/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0112 - val_loss: 0.0167
# Epoch 71/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0134 - val_loss: 0.0196
# Epoch 72/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0120 - val_loss: 0.0166
# Epoch 73/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0083 - val_loss: 0.0184
# Epoch 74/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0107 - val_loss: 0.0179
# Epoch 75/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0092 - val_loss: 0.0179
# Epoch 76/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0092 - val_loss: 0.0177
# Epoch 77/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0075 - val_loss: 0.0172
# Epoch 78/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0089 - val_loss: 0.0167
# Epoch 79/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0132 - val_loss: 0.0189
# Epoch 80/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0113 - val_loss: 0.0176
# Epoch 81/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0108 - val_loss: 0.0167
# Epoch 82/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0125 - val_loss: 0.0185
# Epoch 83/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0112 - val_loss: 0.0317
# Epoch 84/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0119 - val_loss: 0.0185
# Epoch 85/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0085 - val_loss: 0.0161
# Epoch 86/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0183 - val_loss: 0.0179
# Epoch 87/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0122 - val_loss: 0.0175
# Epoch 88/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0100 - val_loss: 0.0220
# Epoch 89/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0099 - val_loss: 0.0168
# Epoch 90/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0111 - val_loss: 0.0159
# Epoch 91/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0117 - val_loss: 0.0173
# Epoch 92/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0113 - val_loss: 0.0170
# Epoch 93/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0092 - val_loss: 0.0188
# Epoch 94/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0091 - val_loss: 0.0176
# Epoch 95/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0088 - val_loss: 0.0161
# Epoch 96/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0151 - val_loss: 0.0163
# Epoch 97/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0109 - val_loss: 0.0162
# Epoch 98/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0085 - val_loss: 0.0164
# Epoch 99/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0100 - val_loss: 0.0190
# Epoch 100/100
# 11/11 [==============================] - 18s 2s/step - loss: 0.0098 - val_loss: 0.0148

# %%
# 미리 준비한 모델을 불러오려면 아래 주석을 해제하세요
dir_plus_path = "/content/drive/MyDrive/AIFFEL/GoingDeeper_CV/GD-10/semantic_segmentation/seg_model_unet_plus.h5"
#model_path = dir_path + '/seg_model_unet.h5' 

model_plus = tf.keras.models.load_model(dir_plus_path)

# %%
#def get_output(model, preproc, image_path, output_path):
    # TODO: image_path로 입력된 이미지를 입력받아 preprocess를 해서 model로 infernece한 결과를 시각화하고 
    # 이를 output_path에 저장하는 함수를 작성해주세요.
def get_output(model, preproc, image_path, output_path):
     origin_img = imread(image_path)
     data = {"image":origin_img}
     processed = preproc(**data)
     output = model(np.expand_dims(processed["image"]/255,axis=0))
     output = (output[0].numpy()>0.5).astype(np.uint8).squeeze(-1)*255  #0.5라는 threshold를 변경하면 도로인식 결과범위가 달라집니다.
     output = Image.fromarray(output)
     background = Image.fromarray(origin_img).convert('RGBA')
     output = output.resize((origin_img.shape[1], origin_img.shape[0])).convert('RGBA')
     output = Image.blend(background, output, alpha=0.5)
     output.show()
     return output

# %%
dir_path = "/content/drive/MyDrive/AIFFEL/GoingDeeper_CV/GD-10/semantic_segmentation/data/training"

# 완성한 뒤에는 시각화한 결과를 눈으로 확인해봅시다!
i = 1    # i값을 바꾸면 테스트용 파일이 달라집니다. 
get_output(
     model, 
     test_preproc,
     image_path=dir_path + f'/image_2/00{str(i).zfill(4)}_10.png',
     output_path=dir_path + f'./result_{str(i).zfill(3)}.png'
 )
# Out:
# <PIL.Image.Image image mode=RGBA size=1242x375 at 0x7F6313595690>

# %%
dir_plus_path = "/content/drive/MyDrive/AIFFEL/GoingDeeper_CV/GD-10/semantic_segmentation/data/training"

# 완성한 뒤에는 시각화한 결과를 눈으로 확인해봅시다!
i = 1    # i값을 바꾸면 테스트용 파일이 달라집니다. 
get_output(
     model_plus, 
     test_preproc,
     image_path=dir_plus_path + f'/image_2/00{str(i).zfill(4)}_10.png',
     output_path=dir_plus_path + f'./result_{str(i).zfill(3)}.png'
 )
# Out:
# <PIL.Image.Image image mode=RGBA size=1242x375 at 0x7F631348E510>

# %%
def calculate_iou_score(target, prediction):
    intersection = np.logical_and(target, prediction)
    union = np.logical_or(target, prediction)
    iou_score = float(np.sum(intersection)) / float(np.sum(union))
    print('IoU : %f' % iou_score )
    return iou_score

# %%
def get_output(model, preproc, image_path, output_path, label_path):
    origin_img = imread(image_path)
    data = {"image":origin_img}
    processed = preproc(**data)
    output = model(np.expand_dims(processed["image"]/255,axis=0))
    output = (output[0].numpy()>=0.5).astype(np.uint8).squeeze(-1)*255  #0.5라는 threshold를 변경하면 도로인식 결과범위가 달라집니다.
    prediction = output/255   # 도로로 판단한 영역
    
    output = Image.fromarray(output)
    background = Image.fromarray(origin_img).convert('RGBA')
    output = output.resize((origin_img.shape[1], origin_img.shape[0])).convert('RGBA')
    output = Image.blend(background, output, alpha=0.5)
    output.show()   # 도로로 판단한 영역을 시각화!
     
    if label_path:   
        label_img = imread(label_path)
        label_data = {"image":label_img}
        label_processed = preproc(**label_data)
        label_processed = label_processed["image"]
        target = (label_processed == 7).astype(np.uint8)*1   # 라벨에서 도로로 기재된 영역

        return output, prediction, target
    else:
        return output, prediction, _

# %%
# 완성한 뒤에는 시각화한 결과를 눈으로 확인해봅시다!
i = 1    # i값을 바꾸면 테스트용 파일이 달라집니다. 
output, prediction, target = get_output(
     model, 
     test_preproc,
     image_path=dir_path + f'/image_2/00{str(i).zfill(4)}_10.png',
     output_path=dir_path + f'./result_{str(i).zfill(3)}.png',
     label_path=dir_path + f'/semantic/00{str(i).zfill(4)}_10.png'
 )

calculate_iou_score(target, prediction)
# Out:
# IoU : 0.419641
# 0.41964089410040306

# %%
# 완성한 뒤에는 시각화한 결과를 눈으로 확인해봅시다!
i = 1   # i값을 바꾸면 테스트용 파일이 달라집니다. 
output, prediction, target = get_output(
     model_plus, 
     test_preproc,
     image_path=dir_path + f'/image_2/00{str(i).zfill(4)}_10.png',
     output_path=dir_path + f'./result_{str(i).zfill(3)}.png',
     label_path=dir_path + f'/semantic/00{str(i).zfill(4)}_10.png'
 )

calculate_iou_score(target, prediction)
# Out:
# IoU : 0.900413
# 0.9004127966976264

# %% [markdown]
# * IoU를 비교 해보았을 때, 기본 Unet 모델을 학습시킨 IoU는 0.42 그리고 Unet+ 모델을 학습시킨 IoU는 0.90로 조금 더 좋은 결과를 보여주고 있습니다.
